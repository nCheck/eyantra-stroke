# %%
import pandas as pd
import numpy as np
import matplotlib as plt
from sklearn.model_selection import train_test_split

testData = pd.read_csv("test.csv")
testY = pd.read_csv("output.csv")
trainData = pd.read_csv("train.csv")

# %%
testData = testData.append(testY, sort=False)
testData.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0  36306    Male  80.0           0.0            0.0          Yes
# 1  61829  Female  74.0           0.0            1.0          Yes
# 2  14152  Female  14.0           0.0            0.0           No
# 3  12997    Male  28.0           0.0            0.0           No
# 4  40801  Female  63.0           0.0            0.0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban              83.84  21.1  formerly smoked
# 1  Self-employed          Rural             179.50  26.0  formerly smoked
# 2       children          Rural              95.16  21.2              NaN
# 3        Private          Urban              94.76  23.4              NaN
# 4       Govt_job          Rural              83.57  27.6     never smoked
#
#    stroke
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
