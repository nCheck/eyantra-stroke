# %%
import pandas as pd

df = pd.read_csv('eeg.csv')
data = df['gammaMid']

# %%
df.head()
# Out:
#     timestampMs  poorSignal  eegRawValue  eegRawValueVolts  attention  \
# 0  1.430000e+12           0         -135         -0.000064         79
# 1  1.430000e+12           0           14         -0.000056         64
# 2  1.430000e+12           0         -256         -0.000049         46
# 3  1.430000e+12           0           79         -0.000041         37
# 4  1.430000e+12           0          156         -0.000037         29
#
#    meditation  blinkStrength   delta    theta  alphaLow  alphaHigh  betaLow  \
# 0          56              9  504866   877887     35356       9532    49879
# 1          56              9   66623   877887     35356       9532    49879
# 2          56              9   32568   865877     35359       9532    49879
# 3          56              9   42662  1654598   1320028       9532     6645
# 4          36              9   31548  1654598   1320024       9532   316999
#
#    betaHigh  gammaLow  gammaMid tagEvent location
# ...

# %%
data.median()
# Out:
# 1081652.0
